# %% [markdown]
# # Introduction
# **This will be your workspace for the [Machine Learning course](https://www.kaggle.com/learn/machine-learning).**
#
# You will need to translate the concepts to work with the data in this notebook, the Iowa data. Each page in the Machine Learning course includes instructions for what code to write at that step in the course.
#
# # Write Your Code Below

# %%
import pandas as pd

main_file_path = 'train.csv'
data = pd.read_csv(main_file_path)

# %%
pwd
# Out:
# '/home/yogi/Documents/Kaggle/iowa'

# %%
print (data)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# ...

# %%
print (max(data))
# Out:
# YrSold

# %%
print (data.columns)
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
print (data.SalePrice)
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
# 5       143000
# 6       307000
# 7       200000
# 8       129900
# 9       118000
# 10      129500
# 11      345000
# 12      144000
# 13      279500
# 14      157000
# 15      132000
# 16      149000
# 17       90000
# 18      159000
# 19      139000
# 20      325300
# 21      139400
# 22      230000
# 23      129900
# 24      154000
# 25      256300
# 26      134800
# 27      306000
# 28      207500
# 29       68500
#          ...
# 1430    192140
# 1431    143750
# 1432     64500
# 1433    186500
# 1434    160000
# 1435    174000
# 1436    120500
# 1437    394617
# 1438    149700
# 1439    197000
# 1440    191000
# 1441    149300
# 1442    310000
# 1443    121000
# 1444    179600
# 1445    129000
# 1446    157900
# 1447    240000
# 1448    112000
# 1449     92000
# 1450    136000
# 1451    287090
# 1452    145000
# 1453     84500
# 1454    185000
# 1455    175000
# 1456    210000
# ...

# %%
sale = data.SalePrice

# %%
print (sale.head())
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
new = ['Id','SalePrice']

# %%
new
# Out:
# ['Id', 'SalePrice']

# %%
newdata=data[new]
newdata
# Out:
#         Id  SalePrice
# 0        1     208500
# 1        2     181500
# 2        3     223500
# 3        4     140000
# 4        5     250000
# 5        6     143000
# 6        7     307000
# 7        8     200000
# 8        9     129900
# 9       10     118000
# 10      11     129500
# 11      12     345000
# 12      13     144000
# 13      14     279500
# 14      15     157000
# 15      16     132000
# 16      17     149000
# 17      18      90000
# 18      19     159000
# 19      20     139000
# 20      21     325300
# 21      22     139400
# 22      23     230000
# 23      24     129900
# 24      25     154000
# 25      26     256300
# 26      27     134800
# 27      28     306000
# 28      29     207500
# 29      30      68500
# ...    ...        ...
# 1430  1431     192140
# 1431  1432     143750
# 1432  1433      64500
# 1433  1434     186500
# 1434  1435     160000
# 1435  1436     174000
# 1436  1437     120500
# 1437  1438     394617
# 1438  1439     149700
# ...

# %%
newdata.describe()
# Out:
#                 Id      SalePrice
# count  1460.000000    1460.000000
# mean    730.500000  180921.195890
# std     421.610009   79442.502883
# min       1.000000   34900.000000
# 25%     365.750000  129975.000000
# 50%     730.500000  163000.000000
# 75%    1095.250000  214000.000000
# max    1460.000000  755000.000000

# %%
Y = data.SalePrice

# %%
predictorlist = ['LotArea','YearBuilt','1stFlrSF','2ndFlrSF','FullBath','BedroomAbvGr','TotRmsAbvGrd']

# %%
X = data[predictorlist]

# %%
X
# Out:
#       LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# 0        8450       2003       856       854         2             3
# 1        9600       1976      1262         0         2             3
# 2       11250       2001       920       866         2             3
# 3        9550       1915       961       756         1             3
# 4       14260       2000      1145      1053         2             4
# 5       14115       1993       796       566         1             1
# 6       10084       2004      1694         0         2             3
# 7       10382       1973      1107       983         2             3
# 8        6120       1931      1022       752         2             2
# 9        7420       1939      1077         0         1             2
# 10      11200       1965      1040         0         1             3
# 11      11924       2005      1182      1142         3             4
# 12      12968       1962       912         0         1             2
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
iowamodel = DecisionTreeRegressor()

# %%
iowamodel.fit(X,Y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
X.head()
# Out:
#    LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# 0     8450       2003       856       854         2             3
# 1     9600       1976      1262         0         2             3
# 2    11250       2001       920       866         2             3
# 3     9550       1915       961       756         1             3
# 4    14260       2000      1145      1053         2             4
#
#    TotRmsAbvGrd
# 0             8
# 1             6
# 2             6
# 3             7
# 4             9

# %%
iowamodel.predict(X.head())
# Out:
# array([ 208500.,  181500.,  223500.,  140000.,  250000.])

# %%
from  sklearn.metrics import mean_absolute_error

# %%
prediction = iowamodel.predict(X)

# %%
mean_absolute_error(Y,prediction)
# Out:
# 62.354337899543388

# %%
from sklearn.model_selection import train_test_split

# %%
train_X,val_X,train_Y,val_Y = train_test_split(X,Y,random_state=0 )

# %%
print (train_X.head())
print (val_X.head())
print (train_Y.head())
print (val_Y.head())
# Out:
#       LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# 1292     6600       1892      1378       994         2             4
# 1018    10784       1991       802       670         2             3
# 1213    10246       1965       960         0         0             0
# 1430    21930       2005       734      1104         2             4
# 810     10140       1974      1309         0         1             3
#
#       TotRmsAbvGrd
# 1292            11
# 1018             7
# 1213             3
# 1430             7
# 810              5
#      LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# 529    32668       1957      2515         0         3             4
# 491     9490       1941       958       620         1             3
# 459     7015       1950       979       224         1             3
# 279    10005       1977      1156       866         2             4
# 655     1680       1971       525       567         1             3
#
# ...

# %%
val_X.head()
# Out:
#      LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# 529    32668       1957      2515         0         3             4
# 491     9490       1941       958       620         1             3
# 459     7015       1950       979       224         1             3
# 279    10005       1977      1156       866         2             4
# 655     1680       1971       525       567         1             3
#
#      TotRmsAbvGrd
# 529             9
# 491             5
# 459             5
# 279             8
# 655             6

# %%
#train_X,train_Y,val_X,val_Y = train_test_split(X,Y,random_state=0 )

# %%
#train_X.head()

# %%
#val_X.head()

# %%
iowamodel.fit(train_X, train_Y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
valsetpred = iowamodel.predict(val_X)
print (valsetpred)
# Out:
# [ 335000.  205000.  134800.  205000.   91500.   58500.  350000.  152000.
#   755000.  180000.  230000.  150900.  220000.  130000.  142125.  174000.
#   236000.  142000.  148000.  114504.  135000.  149000.  137000.  189000.
#   139000.  138887.  188000.   92000.  318000.  105500.  165500.  178000.
#   127000.  258000.  253293.  178000.  192500.  127000.  222500.  315750.
#   237500.  165000.  185500.  319000.  335000.  165500.  105500.  111250.
#   154000.  133000.  315750.  154500.  196000.  105000.  193000.   62383.
#   153575.  190000.  148000.   72500.  132500.  150000.  140000.  138800.
#   262000.  174000.  108000.  205950.  107400.  207500.  178000.  109000.
#   124000.  250580.  135750.  250000.  132500.   34900.  325300.  179900.
#   143000.  123000.  153900.  147000.  274970.  189000.   76000.  202500.
#   198900.  144900.  216000.  130500.  174000.  254900.  206000.  140000.
#   190000.  311500.   62383.  137450.  337500.  192140.  168500.  149500.
# ...

# %%
train_X.head()
# Out:
#       LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# 1292     6600       1892      1378       994         2             4
# 1018    10784       1991       802       670         2             3
# 1213    10246       1965       960         0         0             0
# 1430    21930       2005       734      1104         2             4
# 810     10140       1974      1309         0         1             3
#
#       TotRmsAbvGrd
# 1292            11
# 1018             7
# 1213             3
# 1430             7
# 810              5

# %%
val_X.head()
# Out:
#      LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# 529    32668       1957      2515         0         3             4
# 491     9490       1941       958       620         1             3
# 459     7015       1950       979       224         1             3
# 279    10005       1977      1156       866         2             4
# 655     1680       1971       525       567         1             3
#
#      TotRmsAbvGrd
# 529             9
# 491             5
# 459             5
# 279             8
# 655             6

# %%
dtreemodelerror = mean_absolute_error(val_Y,valsetpred)
dtreemodelerror
# Out:
# 33969.24931506849

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(val_Y,valsetpred)
# Out:
# 0.0027397260273972603

# %%
def get_mae(max_leaf_nodes, predictors_train, predictors_val, targ_train, targ_val):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(predictors_train, targ_train)
    preds_val = model.predict(predictors_val)
    mae = mean_absolute_error(targ_val, preds_val)
    return(mae)

# %%
for max_leaf_nodes in [5, 50, 500, 5000]:
    my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_Y, val_Y)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))
# Out:
# Max leaf nodes: 5  		 Mean Absolute Error:  35190
# Max leaf nodes: 50  		 Mean Absolute Error:  27825
# Max leaf nodes: 500  		 Mean Absolute Error:  32662
# Max leaf nodes: 5000  		 Mean Absolute Error:  33382

# %%
for max_leaf_nodes in [35, 40, 50, 60]:
    my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_Y, val_Y)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))
# Out:
# Max leaf nodes: 35  		 Mean Absolute Error:  27556
# Max leaf nodes: 40  		 Mean Absolute Error:  27570
# Max leaf nodes: 50  		 Mean Absolute Error:  27825
# Max leaf nodes: 60  		 Mean Absolute Error:  28072

# %%
for max_leaf_nodes in range(30,40):
    my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_Y, val_Y)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))
# Out:
# Max leaf nodes: 30  		 Mean Absolute Error:  28302
# Max leaf nodes: 31  		 Mean Absolute Error:  27965
# Max leaf nodes: 32  		 Mean Absolute Error:  27852
# Max leaf nodes: 33  		 Mean Absolute Error:  27852
# Max leaf nodes: 34  		 Mean Absolute Error:  27880
# Max leaf nodes: 35  		 Mean Absolute Error:  27556
# Max leaf nodes: 36  		 Mean Absolute Error:  27372
# Max leaf nodes: 37  		 Mean Absolute Error:  27491
# Max leaf nodes: 38  		 Mean Absolute Error:  27509
# Max leaf nodes: 39  		 Mean Absolute Error:  27633

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
forestmodel = RandomForestRegressor()

# %%
forestmodel.fit(train_X,train_Y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
forestprediction = forestmodel.predict(val_X)

# %%
forestprediction
# Out:
# array([ 271000.        ,  151020.        ,  118885.        ,
#         207740.        ,   88740.        ,   94000.        ,
#         231969.2       ,  119340.        ,  683158.1       ,
#         161965.2       ,  220957.8       ,  161880.        ,
#         232910.        ,  126890.        ,  126057.5       ,
#         135875.        ,  237029.        ,  139490.        ,
#         142250.        ,  127240.        ,  116900.8       ,
#         145600.        ,  127540.        ,  184160.        ,
#         146215.        ,  172648.7       ,  180050.        ,
#          84800.        ,  329501.9       ,  109740.        ,
#         133420.        ,  184900.        ,  117950.        ,
#         270355.        ,  326148.3       ,  173007.        ,
#         218507.8       ,  116625.        ,  221850.        ,
#         348689.2       ,  205160.        ,  141217.5       ,
#         187996.5       ,  288440.        ,  362775.1       ,
# ...

# %%
forestmodelerror = mean_absolute_error(val_Y,forestprediction)
forestmodelerror
# Out:
# 23899.614977168949

# %% [markdown]
# **If you have any questions or hit any problems, come to the [Learn Discussion](https://www.kaggle.com/learn-forum) for help. **
#
# **Return to [ML Course Index](https://www.kaggle.com/learn/machine-learning)**
